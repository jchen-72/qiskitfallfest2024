# %% [markdown]
# # PART 0: SETUP
#
# *This part sets up qiskit and the rounds, make sure to run it*

# %% [markdown]
# **Imports**

# %%
from qiskit import *
import RoundList
from qiskit.visualization import plot_bloch_multivector
from qiskit.visualization import plot_histogram
from qiskit_aer import AerSimulator
from qiskit_ibm_runtime import QiskitRuntimeService
from qiskit.quantum_info import Statevector

# %% [markdown]
# **Functions for viewing state**

# %%
def testBloch(circuit):
    state = Statevector(circuit)
    return plot_bloch_multivector(state)

# %%
def testMeasure(circuit):
    circ=circuit.copy()
    circ.measure_all()
    aersim = AerSimulator()
    circ2 = transpile(circ, aersim)
    result_ideal = aersim.run(circ2, shots=1024).result()
    counts_ideal = result_ideal.get_counts()
    return plot_histogram(counts_ideal, title='Result')

# %%
def testDraw(circuit):
    return circuit.draw(initial_state=True, output="mpl")

# %% [markdown]
# #  PART 1
# *Now it is your time to start coding. For each round, 1 through 7, write your code to the circuit assigned at the start.*

# %% [markdown]
# You have several ways to look at the circuits. Use `testDraw(circuit)` and `testBloch(circuit)` (provided in Part 0) at any point in your code, but remember to split your code to have each fully isolated and in its own, or it will not show the output.

# %% [markdown]
# ## Round 1

# %% [markdown]
# This cell loads the round's circuit.

# %%
circuit_1 = RoundList.round_selector(1)

# %% [markdown]
# The original execution results:

# %%
testMeasure(circuit_1)

# %% [markdown]
# *Put your countering gates below:*

# %%
circuit_1.cx(0, 2)
circuit_1.cx(0, 1)
circuit_1.h(0)

# %% [markdown]
# The final execution results after running your code:

# %%
testMeasure(circuit_1)

# %% [markdown]
# ## Round 2

# %% [markdown]
# This cell loads the round's circuit.

# %%
circuit_2 = RoundList.round_selector(2)

# %% [markdown]
# The original execution results:

# %%
testMeasure(circuit_2)

# %% [markdown]
# *Put your countering gates below:*

# %%
circuit_2.cx(1, 2)
circuit_2.cx(0, 1)
circuit_2.h(0)

# %% [markdown]
# The final execution results after running your code:

# %%
testMeasure(circuit_2)

# %% [markdown]
# ## Round 3

# %% [markdown]
# This cell loads the round's circuit.

# %%
circuit_3 = RoundList.round_selector(3)

# %% [markdown]
# The original execution results:

# %%
testMeasure(circuit_3)

# %% [markdown]
# *Put your countering gates below:*

# %%
circuit_3.cx(0,1)
circuit_3.h(2)
circuit_3.ch(0,2)
circuit_3.cx(0,2)
circuit_3.h(0)
##probably wrong never got to finish

# %% [markdown]
# The final execution results after running your code:

# %%
testMeasure(circuit_3)

# %% [markdown]
# ## Round 4

# %% [markdown]
# This cell loads the round's circuit.

# %%
circuit_4 = RoundList.round_selector(4)

# %% [markdown]
# The original execution results:

# %%
testMeasure(circuit_4)

# %% [markdown]
# *Put your countering gates below:*

# %%
circuit_4.cx(0,1)
circuit_4.h(2)
circuit_4.h(0)
circuit_4.rx(-3.14169265358979323/4, 0)

# %% [markdown]
# The final execution results after running your code:

# %%
testMeasure(circuit_4)

# %% [markdown]
# ## Round 5

# %% [markdown]
# This cell loads the round's circuit.

# %%
circuit_5 = RoundList.round_selector(5)

# %% [markdown]
# The original execution results:

# %%
testMeasure(circuit_5)

# %% [markdown]
# *Put your countering gates below:*

# %%
circuit_5.rx(3.14159265358979323, 2)       
circuit_5.cx(1, 2)    
circuit_5.cx(0, 1)         
circuit_5.h(0)

# %% [markdown]
# The final execution results after running your code:

# %%
testMeasure(circuit_5)

# %% [markdown]
# ## Round 6

# %% [markdown]
# This cell loads the round's circuit.

# %%
circuit_6 = RoundList.round_selector(6)

# %% [markdown]
# The original execution results:

# %%
testMeasure(circuit_6)

# %% [markdown]
# *Put your countering gates below:*

# %%
circuit_6.ccx(0, 1, 2)
circuit_6.x(1)
circuit_6.ccx(0, 2, 4)
circuit_6.h(2)
circuit_6.h(3)

# %% [markdown]
# The final execution results after running your code:

# %%
testMeasure(circuit_6)

# %% [markdown]
# ## Round 7

# %% [markdown]
# This cell loads the round's circuit.

# %%
circuit_7 = RoundList.round_selector(7)

# %% [markdown]
# The original execution results:

# %%
testMeasure(circuit_7)

# %% [markdown]
# *Put your countering gates below:*

# %%
##Your Code Here

# %% [markdown]
# The final execution results after running your code:

# %%
testMeasure(circuit_7)

# %% [markdown]
# # Congratulations, you have reached the end of Stage 1!
# To recieve a certificate, share your github repository with these files with Zhar-ptitsa before **Thursday 11/14 3:45**
#
# *After that, Stage 2 will occur in-person*
